# %%
import numpy as np
import pandas as pd
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
labels  = ['Student A', 'Student B', 'Student C', 'Student D']
e1 = pd.Series(exam1,labels)
e2 = pd.Series(exam2,labels)
d = {s:p for s,p in zip(labels,exam1)}
df = pd.DataFrame({'e1':exam1, 'e2':exam2},index=labels)
data = np.array([exam1,exam2])
df['e3'] = [67,59,79,84]
df['semester1'] = df['e1'] + df['e2'] + df['e3']
df[(df['e2']<50)|(df['e2']>90)]
# Out:
#            e1  e2  e3  semester1
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.drop('semester1',axis=1)
# Out:
#            e1  e2  e3
# Student A  89  74  67
# Student B  85  56  59
# Student C  93  44  79
# Student D  83  92  84

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.drop(['e3','semester1'],axis=1,inplace=True)
df
# Out:
#            e1  e2
# Student A  89  74
# Student B  85  56
# Student C  93  44
# Student D  83  92

# %%
df.drop('Student B',inplace=True)
df
# Out:
#            e1  e2
# Student A  89  74
# Student C  93  44
# Student D  83  92

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    level_0      index  e1  e2
# 0        0  Student A  89  74
# 1        1  Student C  93  44
# 2        2  Student D  83  92

# %%
df
# Out:
#    level_0      index  e1  e2
# 0        0  Student A  89  74
# 1        1  Student C  93  44
# 2        2  Student D  83  92

# %%
df
# Out:
#    level_0      index  e1  e2
# 0        0  Student A  89  74
# 1        1  Student C  93  44
# 2        2  Student D  83  92

# %%
df.drop('level_0',axis=1,inplace=True)

# %%
df
# Out:
#        index  e1  e2
# 0  Student A  89  74
# 1  Student C  93  44
# 2  Student D  83  92

# %%
df.reset_index()
# Out:
#    level_0      index  e1  e2
# 0        0  Student A  89  74
# 1        1  Student C  93  44
# 2        2  Student D  83  92

# %%
df
# Out:
#        index  e1  e2
# 0  Student A  89  74
# 1  Student C  93  44
# 2  Student D  83  92

# %%
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
labels  = ['Student A', 'Student B', 'Student C', 'Student D']
e1 = pd.Series(exam1,labels)
e2 = pd.Series(exam2,labels)
d = {s:p for s,p in zip(labels,exam1)}
df = pd.DataFrame({'e1':exam1, 'e2':exam2},index=labels)
data = np.array([exam1,exam2])
df['e3'] = [67,59,79,84]
df['semester1'] = df['e1'] + df['e2'] + df['e3']
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.reset_index()
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index = df.reset_index()
df_new_index
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index['student_name'] = ['Adrian','Bartłomiej','Celina','Dagmara']
df_new_index
# Out:
#        index  e1  e2  e3  semester1 student_name
# 0  Student A  89  74  67        230       Adrian
# 1  Student B  85  56  59        200   Bartłomiej
# 2  Student C  93  44  79        216       Celina
# 3  Student D  83  92  84        259      Dagmara

# %%
df_new_index.set_index('student_name')
# Out:
#                   index  e1  e2  e3  semester1
# student_name
# Adrian        Student A  89  74  67        230
# Bartłomiej    Student B  85  56  59        200
# Celina        Student C  93  44  79        216
# Dagmara       Student D  83  92  84        259

# %%
df_new_index2 = df.reset_index()
df_new_index2
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index2.index = ['Adrian','Bartłomiej','Celina','Dagmara']
df_new_index2
# Out:
#                 index  e1  e2  e3  semester1
# Adrian      Student A  89  74  67        230
# Bartłomiej  Student B  85  56  59        200
# Celina      Student C  93  44  79        216
# Dagmara     Student D  83  92  84        259

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.rename(columns={'e1':'exam1','e2':'exam2','e3':'exam3'})
# Out:
#            exam1  exam2  exam3  semester1
# Student A     89     74     67        230
# Student B     85     56     59        200
# Student C     93     44     79        216
# Student D     83     92     84        259

# %%
df.rename(str.upper, axis='columns')
# Out:
#            E1  E2  E3  SEMESTER1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df = pd.DataFrame({'A':[100,44,56,99,85,100],
                  'B':['Panda','Snake','Snake','Rat','Dog','Panda']})

# %%
df
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
df['B'].value_counts()
# Out:
# B
# Panda    2
# Snake    2
# Rat      1
# Dog      1
# Name: count, dtype: int64

# %%
df['B'].value_counts(normalize=True)
# Out:
# B
# Panda    0.333333
# Snake    0.333333
# Rat      0.166667
# Dog      0.166667
# Name: proportion, dtype: float64

# %%
df.sort_values(by='A',ascending=False)
# Out:
#      A      B
# 0  100  Panda
# 5  100  Panda
# 3   99    Rat
# 4   85    Dog
# 2   56  Snake
# 1   44  Snake

# %%
df.drop_duplicates()
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog

# %%
df
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
df.drop_duplicates(keep="last")
# Out:
#      A      B
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
df
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
exam3=[67,59,79,84]
df = pd.DataFrame({'e1':exam1, 'e2':exam2, 'e3':exam3}, index=labels)
df['semester1'] = df['e1']+df['e2']+df['e3']
schools = ['High School X','High School X','High School Y','High School Y']
multi_index_list = [(school,student) for school,student in zip(schools,df.index)]
df.index = pd.MultiIndex.from_tuples(multi_index_list,names=['School','Student'])
df
# Out:
#                          e1  e2  e3  semester1
# School        Student
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.loc['High School X']
# Out:
#            e1  e2  e3  semester1
# Student
# Student A  89  74  67        230
# Student B  85  56  59        200

# %%
df.loc['High School X'].iloc[1]
# Out:
# e1            85
# e2            56
# e3            59
# semester1    200
# Name: Student B, dtype: int64

# %%
import random
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
exam3 = [67,59,79,84]
exam4 = []
exam5 = []
exam6 = []
for i in range(0,4):
    exam4.append(random.randint(1,100))
    exam5.append(random.randint(1,100))
    exam6.append(random.randint(1,100))
df = pd.DataFrame({'e1':exam1, 'e2':exam2, 'e3':exam3,'e4':exam4,'e5':exam5,'e6':exam6}, index=labels)
df['semester1'] = df['e1']+df['e2']+df['e3']
df['semester2'] = df['e4']+df['e5']+df['e6']
schools = ['High School X','High School X','High School Y','High School Y']
multi_index_list = [(school,student) for school,student in zip(schools,df.index)]
df.index = pd.MultiIndex.from_tuples(multi_index_list,names=['School','Student'])
df
# Out:
#                          e1  e2  e3  e4  e5  e6  semester1  semester2
# School        Student
# High School X Student A  89  74  67   4  33  84        230        121
#               Student B  85  56  59  52   1  79        200        132
# High School Y Student C  93  44  79  69  96  85        216        250
#               Student D  83  92  84  72  46  41        259        159

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'Category':['Games','Games','Games',

                               'Film&Video','Film&Video','Film&Video'],

                  'Project_Title':['The Last Faith','Magic Puzzles','Dinosaur Fossil Hunter',

                                   'Beyond Your Eyes','5150','8-Bit Wars'],

                  'Pledged':[92774,2873519,7962,

                             276,23963,6950],

                  'Country':['UK','USA','Poland',

                             'Bulgaria','USA','UK'],

                  'Date_Start':['2020-03-21','2020-03-11','2020-04-16',

                                '2020-02-09','2020-04-10','2020-03-19']})

# %%
df
# Out:
#      Category           Project_Title  Pledged   Country  Date_Start
# 0       Games          The Last Faith    92774        UK  2020-03-21
# 1       Games           Magic Puzzles  2873519       USA  2020-03-11
# 2       Games  Dinosaur Fossil Hunter     7962    Poland  2020-04-16
# 3  Film&Video        Beyond Your Eyes      276  Bulgaria  2020-02-09
# 4  Film&Video                    5150    23963       USA  2020-04-10
# 5  Film&Video              8-Bit Wars     6950        UK  2020-03-19

# %%
df.groupby('Category')

# %%
df.groupby('Category').count()
# Out:
#             Project_Title  Pledged  Country  Date_Start
# Category
# Film&Video              3        3        3           3
# Games                   3        3        3           3

# %%
df[['Category',"Pledged"]].groupby("Category").sum()
# Out:
#             Pledged
# Category
# Film&Video    31189
# Games       2974255

# %%
df['Date_Start'] = pd.to_datetime(df['Date_Start'])
df[["Pledged",'Date_Start']].groupby(pd.Grouper(key='Date_Start',freq='M')).sum()
df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
# Out:
# C:\Users\Michal Krzyzanowski\AppData\Local\Temp\ipykernel_20468\318576129.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df[["Pledged",'Date_Start']].groupby(pd.Grouper(key='Date_Start',freq='M')).sum()
# C:\Users\Michal Krzyzanowski\AppData\Local\Temp\ipykernel_20468\318576129.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.groupby(pd.Grouper(key='Date_Start',freq='M')).agg({'Pledged':'sum','Project_Title':'count'})
#             Pledged  Project_Title
# Date_Start
# 2020-02-29      276              1
# 2020-03-31  2973243              3
# 2020-04-30    31925              2

# %%
df.groupby(['Country','Category']).sum(["Pledged"])
# Out:
#                      Pledged
# Country  Category
# Bulgaria Film&Video      276
# Poland   Games          7962
# UK       Film&Video     6950
#          Games         92774
# USA      Film&Video    23963
#          Games       2873519

# %%
df_with_nulls = pd.DataFrame({'A':[1,100,np.nan,1000,10000],
                             'B':[2,4,2,4,np.nan],
                             'C':[40,np.nan,20,np.nan,np.nan]})
df_with_nulls
# Out:
#          A    B     C
# 0      1.0  2.0  40.0
# 1    100.0  4.0   NaN
# 2      NaN  2.0  20.0
# 3   1000.0  4.0   NaN
# 4  10000.0  NaN   NaN

# %%
df_with_nulls.isnull().mean()
df_with_nulls.isnull().sum()
# Out:
# A    1
# B    1
# C    3
# dtype: int64

# %%
df_with_nulls[df_with_nulls['C'].isnull()]
# Out:
#          A    B   C
# 1    100.0  4.0 NaN
# 3   1000.0  4.0 NaN
# 4  10000.0  NaN NaN

# %%
import pandas as pd
import numpy as np
import missingno as msno
df_with_nulls = pd.DataFrame({'A':[1,100,np.nan,1000,10000],
                             'B':[2,4,2,4,np.nan],
                             'C':[40,np.nan,20,np.nan,np.nan]})
msno.matrix(df_with_nulls)
# Out:
# <Axes: >

# %%
df_with_nulls.dropna()
# Out:
#      A    B     C
# 0  1.0  2.0  40.0

# %%
df_with_nulls.dropna(thresh=2)
# Out:
#         A    B     C
# 0     1.0  2.0  40.0
# 1   100.0  4.0   NaN
# 2     NaN  2.0  20.0
# 3  1000.0  4.0   NaN

# %%
df_with_nulls.fillna('NEW')
# Out:
#          A    B     C
# 0      1.0  2.0  40.0
# 1    100.0  4.0   NEW
# 2      NEW  2.0  20.0
# 3   1000.0  4.0   NEW
# 4  10000.0  NEW   NEW

# %%
df_with_nulls['B'].fillna(df_with_nulls['B'].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    2.0
# 3    4.0
# 4    3.0
# Name: B, dtype: float64

# %%
import pandas as pd
df = pd.read_excel('myExcelFile.xlsx', sheet_name='my_data')
df.to_excel('myNewExcelFile.xlsx', sheet_name='my_new_data')
df
# Out:
#      A    B    C
# 0    0    0    0
# 1    1    1   50
# 2    2    4  100
# 3    3    9  150
# 4    4   16  200
# 5    5   25  250
# 6    6   36  300
# 7    7   49  350
# 8    8   64  400
# 9    9   81  450
# 10  10  100  500

# %%
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='my_dfs')
df.to_excel(writer, sheet_name='my_dfs', startcol=6, startrow=5, index=False)

# %%
writer.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 writer.save()
#
# AttributeError: 'XlsxWriter' object has no attribute 'save'

# %%
writer.close()

# %%
df
# Out:
#      A    B    C
# 0    0    0    0
# 1    1    1   50
# 2    2    4  100
# 3    3    9  150
# 4    4   16  200
# 5    5   25  250
# 6    6   36  300
# 7    7   49  350
# 8    8   64  400
# 9    9   81  450
# 10  10  100  500

# %%
writer.close()

# %%
writer = pd.ExcelWriter('add_chart.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='my_chart')

# %%
workbook = writer.book
worksheet = writer.sheets['my_chart']

# %%
chart = workbook.add_chart({'type':'line'})

# %%
def grab_series(df, sheet_name, colname, startcol=0, startrow=0):

    col_index = df.columns.tolist().index(colname)
    col_letter = chr(ord('@')+(col_index+2+startcol))
    first_row = startrow + 2
    last_row = startrow + 1 + len(df)
    return f"='{sheet_name}'!{col_letter}{first_row}:{col_letter}{last_row}"

# %%
chart.add_series({'values':grab_series(df,'my_chart','B')})

# %%
chart.set_x_axis({
    'name': 'x^2',
    'name_font': {'size': 14, 'bold': True},
    'num_font':  {'italic': True },
})

# %%
chart.set_legend({'none': True})

# %%
worksheet.insert_chart('F2', chart)
# Out:
# 0

# %%
writer.close()
workbook.close()
# Out:
# C:\Kodilla\kurs_python\env\Lib\site-packages\xlsxwriter\workbook.py:369: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
writer = pd.ExcelWriter('conditional_format.xlsx', engine='xlsxwriter')

df.to_excel(writer, sheet_name='my_conditional')

workbook = writer.book
worksheet = writer.sheets['my_conditional']

# %%
format1 = workbook.add_format({'bg_color':   '#FFC7CE',
                               'font_color': '#9C0006'})

# %%
worksheet.conditional_format("D2:D12",{'type': 'cell',
                                      'criteria':'>=',
                                      'value':300,
                                      'format':format1})
# Out:
# 0

# %%
worksheet.write_string('A16','Enter an integer greater than 0:')
worksheet.data_validation('B16', {
    'validate':'integer',
    'criteria':'>',
    'value':0
})
worksheet.set_column('A:A',35)
writer.close()

# %%
data = pd.read_html('https://pl.wikipedia.org/wiki/Miasta_w_Polsce', header=0)
data[0]
# Out:
#     Lp.     Miasto         Województwo Liczba mieszkańców  \
# 0   1.0   Warszawa         mazowieckie          1 861 975
# 1   2.0     Kraków         małopolskie            803 282
# 2   3.0    Wrocław        dolnośląskie            674 079
# 3   4.0       Łódź             łódzkie            658 444
# 4   5.0     Poznań       wielkopolskie            541 316
# 5   6.0     Gdańsk           pomorskie            486 345
# 6   7.0   Szczecin  zachodniopomorskie            391 566
# 7   8.0     Lublin           lubelskie            331 243
# 8   9.0  Bydgoszcz  kujawsko-pomorskie            330 038
# 9  10.0  Białystok           podlaskie            292 600
#
#   Gęstość zaludnienia [osoby/km²]
# 0                           3 600
# 1                           2 458
# 2                           2 302
# 3                           2 245
# 4                           2 067
# 5                             712
# 6                           1 303
# 7                           2 246
# 8                           1 876
# 9                           2 865

# %%
data[1]
# Out:
#     Lp.        Miasto         Województwo Powierzchnia [ha]
# 0   1.0        Gdańsk           pomorskie            68 300
# 1   2.0      Warszawa         mazowieckie            51 720
# 2   3.0        Gdynia           pomorskie            39 151
# 3   4.0        Kraków         małopolskie            32 685
# 4   5.0      Szczecin  zachodniopomorskie            30 062
# 5   6.0          Łódź             łódzkie            29 325
# 6   7.0       Wrocław        dolnośląskie            29 281
# 7   8.0  Zielona Góra            lubuskie            27 827
# 8   9.0        Poznań       wielkopolskie            26 191
# 9  10.0   Świnoujście  zachodniopomorskie            20 207

# %%
titles = pd.read_html("https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/", header=0)
titles[0]
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#     YEAR  HIGH POSN
# 0   1981          1
# 1   1992          1
# 2   1967          1
# 3   2011          1
# 4   1995          1
# 5   1982          1
# 6   1973          2
# 7   1985          1
# 8   1987          1
# 9   1991          1
# 10  1977          1
# 11  1990          1
# 12  2006          1
# 13  1991          1
# 14  1997          1
# 15  1984          1
# 16  2004          1
# 17  1997          1
# 18  1977          9
# 19  2000          1
# 20  1970          1
# 21  1987          4
# 22  2007          1
# 23  2009          1
# 24  2000          1
# 25  1998          1
# 26  2015          1
# 27  1997          1
# 28  1996          1
# 29  2008          1
# 30  2002          1
# 31  2003          1
# 32  2008          1
# 33  2006          1
# 34  2004          1
# 35  1987          1
# 36  1978          5
# 37  2004          1
# 38  1989          1
# 39  2005          1
# 40  1995          1
# 41  1973          1
# 42  1999          1
# 43  1988          1
# 44  2000          1
# 45  1975          1
# 46  1977          1
# 47  1998          1
# 48  2014          1
# 49  2002          1
# 50  1986          1
# 51  1965          1
# 52  1998          1
# 53  1987          1
# 54  2000          1
# 55  2001          1
# 56  2010          1
# 57  2006          1
# 58  2005          2
# 59  1992          1

# %%
type(titles)
# Out:
# list

# %%
titles
# Out:
# [    POS                                   TITLE                    ARTIST  \
#  0     1                           GREATEST HITS                     QUEEN
#  1     2                    GOLD - GREATEST HITS                      ABBA
#  2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
#  3     4                                      21                     ADELE
#  4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
#  5     6                                THRILLER           MICHAEL JACKSON
#  6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
#  7     8                        BROTHERS IN ARMS              DIRE STRAITS
#  8     9                                     BAD           MICHAEL JACKSON
#  9    10                        GREATEST HITS II                     QUEEN
#  10   11                                 RUMOURS             FLEETWOOD MAC
#  11   12               THE IMMACULATE COLLECTION                   MADONNA
#  12   13                           BACK TO BLACK             AMY WINEHOUSE
#  13   14                                   STARS                SIMPLY RED
#  14   15                            COME ON OVER              SHANIA TWAIN
#  15   16                                  LEGEND  BOB MARLEY & THE WAILERS
#  16   17                          BACK TO BEDLAM               JAMES BLUNT
#  17   18                             URBAN HYMNS                     VERVE
#  18   19                         BAT OUT OF HELL                 MEAT LOAF
#  19   20                                       1                   BEATLES
#  20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
#  21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
#  22   23                                  SPIRIT               LEONA LEWIS
#  23   24                              CRAZY LOVE             MICHAEL BUBLE
#  24   25                                NO ANGEL                      DIDO
#  25   26                            WHITE LADDER                DAVID GRAY
#  26   27                                      25                     ADELE
#  27   28                         TALK ON CORNERS                     CORRS
#  28   29                                   SPICE               SPICE GIRLS
#  29   30                                THE FAME                 LADY GAGA
#  30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
#  31   32                           LIFE FOR RENT                      DIDO
#  32   33                       ONLY BY THE NIGHT             KINGS OF LEON
#  33   34                         BEAUTIFUL WORLD                 TAKE THAT
#  34   35                         HOPES AND FEARS                     KEANE
#  35   36                         THE JOSHUA TREE                        U2
#  36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
#  37   38                         SCISSOR SISTERS           SCISSOR SISTERS
#  38   39                           BUT SERIOUSLY              PHIL COLLINS
#  39   40                                     X&Y                  COLDPLAY
#  40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
#  41   42                           TUBULAR BELLS             MIKE OLDFIELD
#  42   43                             THE MAN WHO                    TRAVIS
#  43   44                           TRACY CHAPMAN             TRACY CHAPMAN
#  44   45                              PARACHUTES                  COLDPLAY
#  45   46                           GREATEST HITS                      ABBA
#  46   47                                  GREASE       ORIGINAL SOUNDTRACK
#  47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
#  48   49                                       X                ED SHEERAN
#  49   50                       COME AWAY WITH ME               NORAH JONES
#  50   51                               GRACELAND                PAUL SIMON
#  51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
#  52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
#  53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
#  54   55                 THE MARSHALL MATHERS LP                    EMINEM
#  55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
#  56   57                                PROGRESS                 TAKE THAT
#  57   58                               EYES OPEN               SNOW PATROL
#  58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
#  59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#      YEAR  HIGH POSN
#  0   1981          1
#  1   1992          1
#  2   1967          1
#  3   2011          1
#  4   1995          1
#  5   1982          1
#  6   1973          2
#  7   1985          1
#  8   1987          1
#  9   1991          1
#  10  1977          1
#  11  1990          1
#  12  2006          1
#  13  1991          1
#  14  1997          1
#  15  1984          1
#  16  2004          1
#  17  1997          1
#  18  1977          9
#  19  2000          1
#  20  1970          1
#  21  1987          4
#  22  2007          1
#  23  2009          1
#  24  2000          1
#  25  1998          1
#  26  2015          1
#  27  1997          1
#  28  1996          1
#  29  2008          1
#  30  2002          1
#  31  2003          1
#  32  2008          1
#  33  2006          1
#  34  2004          1
#  35  1987          1
#  36  1978          5
#  37  2004          1
#  38  1989          1
#  39  2005          1
#  40  1995          1
#  41  1973          1
#  42  1999          1
#  43  1988          1
#  44  2000          1
#  45  1975          1
#  46  1977          1
#  47  1998          1
#  48  2014          1
#  49  2002          1
#  50  1986          1
#  51  1965          1
#  52  1998          1
#  53  1987          1
#  54  2000          1
#  55  2001          1
#  56  2010          1
#  57  2006          1
#  58  2005          2
#  59  1992          1  ]

# %%
df = pd.DataFrame(titles[0])

# %%
df
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#     YEAR  HIGH POSN
# 0   1981          1
# 1   1992          1
# 2   1967          1
# 3   2011          1
# 4   1995          1
# 5   1982          1
# 6   1973          2
# 7   1985          1
# 8   1987          1
# 9   1991          1
# 10  1977          1
# 11  1990          1
# 12  2006          1
# 13  1991          1
# 14  1997          1
# 15  1984          1
# 16  2004          1
# 17  1997          1
# 18  1977          9
# 19  2000          1
# 20  1970          1
# 21  1987          4
# 22  2007          1
# 23  2009          1
# 24  2000          1
# 25  1998          1
# 26  2015          1
# 27  1997          1
# 28  1996          1
# 29  2008          1
# 30  2002          1
# 31  2003          1
# 32  2008          1
# 33  2006          1
# 34  2004          1
# 35  1987          1
# 36  1978          5
# 37  2004          1
# 38  1989          1
# 39  2005          1
# 40  1995          1
# 41  1973          1
# 42  1999          1
# 43  1988          1
# 44  2000          1
# 45  1975          1
# 46  1977          1
# 47  1998          1
# 48  2014          1
# 49  2002          1
# 50  1986          1
# 51  1965          1
# 52  1998          1
# 53  1987          1
# 54  2000          1
# 55  2001          1
# 56  2010          1
# 57  2006          1
# 58  2005          2
# 59  1992          1

# %%
df.rename(columns={'TITLE': 'TYTUŁ', 'ARTIST': 'ARTYSTA', "YEAR":"ROK", "HIGH POSN":"MAX POZ"},inplace=True)

# %%
df['ARTYSTA'].nunique()
# Out:
# 47

# %%
df
# Out:
#     POS                                   TITLE                    ARTIST  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#     YEAR  HIGH POSN
# 0   1981          1
# 1   1992          1
# 2   1967          1
# 3   2011          1
# 4   1995          1
# 5   1982          1
# 6   1973          2
# 7   1985          1
# 8   1987          1
# 9   1991          1
# 10  1977          1
# 11  1990          1
# 12  2006          1
# 13  1991          1
# 14  1997          1
# 15  1984          1
# 16  2004          1
# 17  1997          1
# 18  1977          9
# 19  2000          1
# 20  1970          1
# 21  1987          4
# 22  2007          1
# 23  2009          1
# 24  2000          1
# 25  1998          1
# 26  2015          1
# 27  1997          1
# 28  1996          1
# 29  2008          1
# 30  2002          1
# 31  2003          1
# 32  2008          1
# 33  2006          1
# 34  2004          1
# 35  1987          1
# 36  1978          5
# 37  2004          1
# 38  1989          1
# 39  2005          1
# 40  1995          1
# 41  1973          1
# 42  1999          1
# 43  1988          1
# 44  2000          1
# 45  1975          1
# 46  1977          1
# 47  1998          1
# 48  2014          1
# 49  2002          1
# 50  1986          1
# 51  1965          1
# 52  1998          1
# 53  1987          1
# 54  2000          1
# 55  2001          1
# 56  2010          1
# 57  2006          1
# 58  2005          2
# 59  1992          1

# %%
df['ARTYSTA'].value_counts()
# Out:
# ARTYSTA
# COLDPLAY                    3
# TAKE THAT                   3
# FLEETWOOD MAC               2
# ABBA                        2
# DIDO                        2
# ORIGINAL SOUNDTRACK         2
# QUEEN                       2
# ROBBIE WILLIAMS             2
# BEATLES                     2
# MICHAEL JACKSON             2
# ADELE                       2
# SNOW PATROL                 1
# KEANE                       1
# U2                          1
# JEFF WAYNE                  1
# SCISSOR SISTERS             1
# PHIL COLLINS                1
# GEORGE MICHAEL              1
# EMINEM                      1
# MIKE OLDFIELD               1
# TRAVIS                      1
# TRACY CHAPMAN               1
# ED SHEERAN                  1
# NORAH JONES                 1
# PAUL SIMON                  1
# ORIGINAL CAST RECORDING     1
# ALANIS MORISSETTE           1
# CORRS                       1
# KINGS OF LEON               1
# BOB MARLEY & THE WAILERS    1
# OASIS                       1
# PINK FLOYD                  1
# DIRE STRAITS                1
# MADONNA                     1
# AMY WINEHOUSE               1
# SIMPLY RED                  1
# SHANIA TWAIN                1
# JAMES BLUNT                 1
# LADY GAGA                   1
# VERVE                       1
# MEAT LOAF                   1
# SIMON & GARFUNKEL           1
# LEONA LEWIS                 1
# MICHAEL BUBLE               1
# DAVID GRAY                  1
# SPICE GIRLS                 1
# REM                         1
# Name: count, dtype: int64

# %%
for i in df:
    i.capitalize()
df
# Out:
#     POS                                   TYTUŁ                   ARTYSTA  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#      ROK  MAX POZ
# 0   1981        1
# 1   1992        1
# 2   1967        1
# 3   2011        1
# 4   1995        1
# 5   1982        1
# 6   1973        2
# 7   1985        1
# 8   1987        1
# 9   1991        1
# 10  1977        1
# 11  1990        1
# 12  2006        1
# 13  1991        1
# 14  1997        1
# 15  1984        1
# 16  2004        1
# 17  1997        1
# 18  1977        9
# 19  2000        1
# 20  1970        1
# 21  1987        4
# 22  2007        1
# 23  2009        1
# 24  2000        1
# 25  1998        1
# 26  2015        1
# 27  1997        1
# 28  1996        1
# 29  2008        1
# 30  2002        1
# 31  2003        1
# 32  2008        1
# 33  2006        1
# 34  2004        1
# 35  1987        1
# 36  1978        5
# 37  2004        1
# 38  1989        1
# 39  2005        1
# 40  1995        1
# 41  1973        1
# 42  1999        1
# 43  1988        1
# 44  2000        1
# 45  1975        1
# 46  1977        1
# 47  1998        1
# 48  2014        1
# 49  2002        1
# 50  1986        1
# 51  1965        1
# 52  1998        1
# 53  1987        1
# 54  2000        1
# 55  2001        1
# 56  2010        1
# 57  2006        1
# 58  2005        2
# 59  1992        1

# %%
df.rename(str.capitalize, axis='columns',inplace=True)

# %%
df.drop(["Max poz"],axis=1,inplace=True)
df
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#      Rok
# 0   1981
# 1   1992
# 2   1967
# 3   2011
# 4   1995
# 5   1982
# 6   1973
# 7   1985
# 8   1987
# 9   1991
# 10  1977
# 11  1990
# 12  2006
# 13  1991
# 14  1997
# 15  1984
# 16  2004
# 17  1997
# 18  1977
# 19  2000
# 20  1970
# 21  1987
# 22  2007
# 23  2009
# 24  2000
# 25  1998
# 26  2015
# 27  1997
# 28  1996
# 29  2008
# 30  2002
# 31  2003
# 32  2008
# 33  2006
# 34  2004
# 35  1987
# 36  1978
# 37  2004
# 38  1989
# 39  2005
# 40  1995
# 41  1973
# 42  1999
# 43  1988
# 44  2000
# 45  1975
# 46  1977
# 47  1998
# 48  2014
# 49  2002
# 50  1986
# 51  1965
# 52  1998
# 53  1987
# 54  2000
# 55  2001
# 56  2010
# 57  2006
# 58  2005
# 59  1992

# %%
df["Rok"].value_counts()
# Out:
# Rok
# 2000    4
# 1987    4
# 2006    3
# 1977    3
# 1998    3
# 2004    3
# 1997    3
# 2008    2
# 2005    2
# 1992    2
# 2002    2
# 1991    2
# 1973    2
# 1995    2
# 1975    1
# 2003    1
# 1988    1
# 2014    1
# 1999    1
# 1986    1
# 1965    1
# 1989    1
# 1978    1
# 2001    1
# 1981    1
# 2007    1
# 1996    1
# 2015    1
# 2009    1
# 1970    1
# 1984    1
# 1990    1
# 1985    1
# 1982    1
# 2011    1
# 1967    1
# 2010    1
# Name: count, dtype: int64

# %%
len(df[(1959<df['Rok'])&(df["Rok"]<1991)])
# Out:
# 22

# %%
(df.sort_values(by='Rok')).iloc[0]["Rok"]
# Out:
# 1965

# %%
df
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 13   14                                   STARS                SIMPLY RED
# 14   15                            COME ON OVER              SHANIA TWAIN
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 17   18                             URBAN HYMNS                     VERVE
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 19   20                                       1                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 22   23                                  SPIRIT               LEONA LEWIS
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 24   25                                NO ANGEL                      DIDO
# 25   26                            WHITE LADDER                DAVID GRAY
# 26   27                                      25                     ADELE
# 27   28                         TALK ON CORNERS                     CORRS
# 28   29                                   SPICE               SPICE GIRLS
# 29   30                                THE FAME                 LADY GAGA
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 34   35                         HOPES AND FEARS                     KEANE
# 35   36                         THE JOSHUA TREE                        U2
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 39   40                                     X&Y                  COLDPLAY
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 42   43                             THE MAN WHO                    TRAVIS
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 44   45                              PARACHUTES                  COLDPLAY
# 45   46                           GREATEST HITS                      ABBA
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 48   49                                       X                ED SHEERAN
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 50   51                               GRACELAND                PAUL SIMON
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 56   57                                PROGRESS                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
#
#      Rok
# 0   1981
# 1   1992
# 2   1967
# 3   2011
# 4   1995
# 5   1982
# 6   1973
# 7   1985
# 8   1987
# 9   1991
# 10  1977
# 11  1990
# 12  2006
# 13  1991
# 14  1997
# 15  1984
# 16  2004
# 17  1997
# 18  1977
# 19  2000
# 20  1970
# 21  1987
# 22  2007
# 23  2009
# 24  2000
# 25  1998
# 26  2015
# 27  1997
# 28  1996
# 29  2008
# 30  2002
# 31  2003
# 32  2008
# 33  2006
# 34  2004
# 35  1987
# 36  1978
# 37  2004
# 38  1989
# 39  2005
# 40  1995
# 41  1973
# 42  1999
# 43  1988
# 44  2000
# 45  1975
# 46  1977
# 47  1998
# 48  2014
# 49  2002
# 50  1986
# 51  1965
# 52  1998
# 53  1987
# 54  2000
# 55  2001
# 56  2010
# 57  2006
# 58  2005
# 59  1992

# %%
df.sort_values(by='Rok',inplace=True)

# %%
df
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 45   46                           GREATEST HITS                      ABBA
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 0     1                           GREATEST HITS                     QUEEN
# 5     6                                THRILLER           MICHAEL JACKSON
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 50   51                               GRACELAND                PAUL SIMON
# 21   22                           DIRTY DANCING       ORIGINAL SOUNDTRACK
# 35   36                         THE JOSHUA TREE                        U2
# 8     9                                     BAD           MICHAEL JACKSON
# 53   54                      TANGO IN THE NIGHT             FLEETWOOD MAC
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 13   14                                   STARS                SIMPLY RED
# 9    10                        GREATEST HITS II                     QUEEN
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 28   29                                   SPICE               SPICE GIRLS
# 27   28                         TALK ON CORNERS                     CORRS
# 14   15                            COME ON OVER              SHANIA TWAIN
# 17   18                             URBAN HYMNS                     VERVE
# 25   26                            WHITE LADDER                DAVID GRAY
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 42   43                             THE MAN WHO                    TRAVIS
# 19   20                                       1                   BEATLES
# 24   25                                NO ANGEL                      DIDO
# 44   45                              PARACHUTES                  COLDPLAY
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 55   56               SWING WHEN YOU'RE WINNING           ROBBIE WILLIAMS
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 30   31             A RUSH OF BLOOD TO THE HEAD                  COLDPLAY
# 31   32                           LIFE FOR RENT                      DIDO
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 34   35                         HOPES AND FEARS                     KEANE
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 39   40                                     X&Y                  COLDPLAY
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 33   34                         BEAUTIFUL WORLD                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 22   23                                  SPIRIT               LEONA LEWIS
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 29   30                                THE FAME                 LADY GAGA
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 56   57                                PROGRESS                 TAKE THAT
# 3     4                                      21                     ADELE
# 48   49                                       X                ED SHEERAN
# 26   27                                      25                     ADELE
#
#      Rok
# 51  1965
# 2   1967
# 20  1970
# 6   1973
# 41  1973
# 45  1975
# 18  1977
# 10  1977
# 46  1977
# 36  1978
# 0   1981
# 5   1982
# 15  1984
# 7   1985
# 50  1986
# 21  1987
# 35  1987
# 8   1987
# 53  1987
# 43  1988
# 38  1989
# 11  1990
# 13  1991
# 9   1991
# 59  1992
# 1   1992
# 4   1995
# 40  1995
# 28  1996
# 27  1997
# 14  1997
# 17  1997
# 25  1998
# 52  1998
# 47  1998
# 42  1999
# 19  2000
# 24  2000
# 44  2000
# 54  2000
# 55  2001
# 49  2002
# 30  2002
# 31  2003
# 37  2004
# 34  2004
# 16  2004
# 39  2005
# 58  2005
# 33  2006
# 57  2006
# 12  2006
# 22  2007
# 32  2008
# 29  2008
# 23  2009
# 56  2010
# 3   2011
# 48  2014
# 26  2015

# %%
df.drop_duplicates("Artysta",inplace=True)
df
# Out:
#     Pos                                   Tytuł                   Artysta  \
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 45   46                           GREATEST HITS                      ABBA
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# 36   37                   THE WAR OF THE WORLDS                JEFF WAYNE
# 0     1                           GREATEST HITS                     QUEEN
# 5     6                                THRILLER           MICHAEL JACKSON
# 15   16                                  LEGEND  BOB MARLEY & THE WAILERS
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 50   51                               GRACELAND                PAUL SIMON
# 35   36                         THE JOSHUA TREE                        U2
# 43   44                           TRACY CHAPMAN             TRACY CHAPMAN
# 38   39                           BUT SERIOUSLY              PHIL COLLINS
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# 13   14                                   STARS                SIMPLY RED
# 59   60                AUTOMATIC FOR THE PEOPLE                       REM
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 40   41                      JAGGED LITTLE PILL         ALANIS MORISSETTE
# 28   29                                   SPICE               SPICE GIRLS
# 27   28                         TALK ON CORNERS                     CORRS
# 14   15                            COME ON OVER              SHANIA TWAIN
# 17   18                             URBAN HYMNS                     VERVE
# 25   26                            WHITE LADDER                DAVID GRAY
# 52   53        LADIES & GENTLEMEN - THE BEST OF            GEORGE MICHAEL
# 47   48                 I'VE BEEN EXPECTING YOU           ROBBIE WILLIAMS
# 42   43                             THE MAN WHO                    TRAVIS
# 24   25                                NO ANGEL                      DIDO
# 44   45                              PARACHUTES                  COLDPLAY
# 54   55                 THE MARSHALL MATHERS LP                    EMINEM
# 49   50                       COME AWAY WITH ME               NORAH JONES
# 37   38                         SCISSOR SISTERS           SCISSOR SISTERS
# 34   35                         HOPES AND FEARS                     KEANE
# 16   17                          BACK TO BEDLAM               JAMES BLUNT
# 58   59  NEVER FORGET - THE ULTIMATE COLLECTION                 TAKE THAT
# 57   58                               EYES OPEN               SNOW PATROL
# 12   13                           BACK TO BLACK             AMY WINEHOUSE
# 22   23                                  SPIRIT               LEONA LEWIS
# 32   33                       ONLY BY THE NIGHT             KINGS OF LEON
# 29   30                                THE FAME                 LADY GAGA
# 23   24                              CRAZY LOVE             MICHAEL BUBLE
# 3     4                                      21                     ADELE
# 48   49                                       X                ED SHEERAN
#
#      Rok
# 51  1965
# 2   1967
# 20  1970
# 6   1973
# 41  1973
# 45  1975
# 18  1977
# 10  1977
# 46  1977
# 36  1978
# 0   1981
# 5   1982
# 15  1984
# 7   1985
# 50  1986
# 35  1987
# 43  1988
# 38  1989
# 11  1990
# 13  1991
# 59  1992
# 4   1995
# 40  1995
# 28  1996
# 27  1997
# 14  1997
# 17  1997
# 25  1998
# 52  1998
# 47  1998
# 42  1999
# 24  2000
# 44  2000
# 54  2000
# 49  2002
# 37  2004
# 34  2004
# 16  2004
# 58  2005
# 57  2006
# 12  2006
# 22  2007
# 32  2008
# 29  2008
# 23  2009
# 3   2011
# 48  2014

# %%
df.to_csv('TopAlbums.csv',index=False)
